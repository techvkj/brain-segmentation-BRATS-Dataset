# %% [markdown]
# # Importing Modules

# %%
import numpy as np
import nibabel as nib                                                     
import itk                                                                
import itkwidgets
from ipywidgets import interact, interactive, IntSlider, ToggleButtons

from skimage.util import montage 
from skimage.transform import rotate

# %matplotlib inline
import seaborn as sns

import matplotlib.pyplot as plt

try:
    get_ipython().run_line_magic("matplotlib inline")
except:
    plt.ion()

# %% [markdown]
# # Modules for model creation

# %%
import keras
import keras.backend as K
from keras.callbacks import CSVLogger
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.models import *
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Conv3D, Dropout, Conv3DTranspose, Activation, BatchNormalization, concatenate, add
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.layers.experimental import preprocessing
from scipy.spatial.distance import directed_hausdorff
import cv2
import os
import tarfile

# %% [markdown]
# # Directory making & files extraction

# %%
# os.mkdir("brain_images")

# %%
# file = tarfile.open('braintumor_dataset\BraTS2021_Training_Data.tar')

# file.extractall('./brain_images')
# file.close()

# %% [markdown]
# # Loading an image from the dataset

# %%
image_path = "brain_images\BraTS2021_00000\BraTS2021_00000_t1.nii.gz"
image_obj = nib.load(image_path)
type(image_obj)
# Out:
# nibabel.nifti1.Nifti1Image

# %%
image_data = image_obj.get_fdata()
print(type(image_data))
image_data.shape
# Out:
# <class 'numpy.ndarray'>
# (240, 240, 155)

# %% [markdown]
# # Real images Visualization

# %%
def visualize_3d(layer):
    plt.figure(figsize=(10, 5))
    plt.imshow(image_data[:, :, layer], cmap='gray');
    plt.axis('off')
    return layer

interact(visualize_3d, layer=(0, image_data.shape[2] - 1));
# Out:
# interactive(children=(IntSlider(value=77, description='layer', max=154), Output()), _dom_classes=('widget-inte…

# %% [markdown]
# # Visualization of segmented part of images

# %%
layer = 50


def visualize_3d_labels(layer):
    mask = nib.load('brain_images\BraTS2021_01574\BraTS2021_01574_seg.nii.gz').get_fdata()
    plt.imshow(mask[:,:,layer])
    plt.axis('off')
    plt.tight_layout()

interact(visualize_3d_labels, layer=(0, image_data.shape[2] - 1));
# Out:
# interactive(children=(IntSlider(value=77, description='layer', max=154), Output()), _dom_classes=('widget-inte…

# %%
fig, ax1 = plt.subplots(1, 1, figsize = (20,20))
ax1.imshow(rotate(montage(image_data[:,:,:]), 90, resize=True), cmap ='gray')

# %%
# dice loss coef
def dice_coef(y_true, y_pred, epsilon=0.00001):
    axis = (0,1,2,3)
    numerator = 2. * K.sum(y_true * y_pred, axis=axis) + epsilon
    denominator = K.sum(y_true*y_true, axis=axis) + K.sum(y_pred*y_pred, axis=axis) + epsilon
    return K.mean((numerator)/(denominator))

# hausdorff dist
def hausdorff(y_true, y_pred):

    try:
        tp = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        pred_p = K.sum(K.round(K.clip(y_pred, 0, 1)))
        haussdorf_dist = tp -pred_p 
        return abs(haussdorf_dist/(128*128))
    except:
        return 1


# Precision 
def precision(y_true, y_pred):
        tp = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        pred_p = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = tp / (pred_p + K.epsilon())
        return precision

    
# Sensitivity      
def sensitivity(y_true, y_pred):
    tp = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possble_p = K.sum(K.round(K.clip(y_true, 0, 1)))
    return tp / (possble_p + K.epsilon())


#  Specificity
def specificity(y_true, y_pred):
    tn = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possble_n= K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return tn / (possble_n+ K.epsilon())

# %% [markdown]
# # Image pre-processing
#
# ### Creating new directories & storing training & validation data

# %%
image_size=128

# %%
# os.mkdir("val_brain_images")

# %%
Training_data_directory = 'brain_images'

# %%
# file = tarfile.open('braintumor_dataset\BraTS2021_00621.tar')
# file.extractall('./val_brain_images')
# file.close()

# %%
Validation_data_directoary = '../val_brain_images'

# %%
train_and_val_directories = [f.path for f in os.scandir(Training_data_directory) if f.is_dir()]
train_and_val_directories
# Out:
# ['brain_images\\BraTS2021_00000',
#  'brain_images\\BraTS2021_00002',
#  'brain_images\\BraTS2021_00003',
#  'brain_images\\BraTS2021_00005',
#  'brain_images\\BraTS2021_00006',
#  'brain_images\\BraTS2021_00008',
#  'brain_images\\BraTS2021_00009',
#  'brain_images\\BraTS2021_00011',
#  'brain_images\\BraTS2021_00012',
#  'brain_images\\BraTS2021_00014',
#  'brain_images\\BraTS2021_00016',
#  'brain_images\\BraTS2021_00017',
#  'brain_images\\BraTS2021_00018',
#  'brain_images\\BraTS2021_00019',
#  'brain_images\\BraTS2021_00020',
#  'brain_images\\BraTS2021_00021',
#  'brain_images\\BraTS2021_00022',
#  'brain_images\\BraTS2021_00024',
#  'brain_images\\BraTS2021_00025',
#  'brain_images\\BraTS2021_00026',
#  'brain_images\\BraTS2021_00028',
#  'brain_images\\BraTS2021_00030',
#  'brain_images\\BraTS2021_00031',
#  'brain_images\\BraTS2021_00032',
#  'brain_images\\BraTS2021_00033',
#  'brain_images\\BraTS2021_00035',
#  'brain_images\\BraTS2021_00036',
#  'brain_images\\BraTS2021_00043',
#  'brain_images\\BraTS2021_00044',
#  'brain_images\\BraTS2021_00045',
#  'brain_images\\BraTS2021_00046',
#  'brain_images\\BraTS2021_00048',
#  'brain_images\\BraTS2021_00049',
#  'brain_images\\BraTS2021_00051',
#  'brain_images\\BraTS2021_00052',
#  'brain_images\\BraTS2021_00053',
#  'brain_images\\BraTS2021_00054',
#  'brain_images\\BraTS2021_00056',
#  'brain_images\\BraTS2021_00058',
#  'brain_images\\BraTS2021_00059',
#  'brain_images\\BraTS2021_00060',
#  'brain_images\\BraTS2021_00061',
#  'brain_images\\BraTS2021_00062',
#  'brain_images\\BraTS2021_00063',
#  'brain_images\\BraTS2021_00064',
#  'brain_images\\BraTS2021_00066',
#  'brain_images\\BraTS2021_00068',
#  'brain_images\\BraTS2021_00070',
#  'brain_images\\BraTS2021_00071',
#  'brain_images\\BraTS2021_00072',
#  'brain_images\\BraTS2021_00074',
#  'brain_images\\BraTS2021_00077',
#  'brain_images\\BraTS2021_00078',
#  'brain_images\\BraTS2021_00081',
#  'brain_images\\BraTS2021_00084',
#  'brain_images\\BraTS2021_00085',
#  'brain_images\\BraTS2021_00087',
#  'brain_images\\BraTS2021_00088',
#  'brain_images\\BraTS2021_00089',
#  'brain_images\\BraTS2021_00090',
#  'brain_images\\BraTS2021_00094',
#  'brain_images\\BraTS2021_00095',
#  'brain_images\\BraTS2021_00096',
#  'brain_images\\BraTS2021_00097',
#  'brain_images\\BraTS2021_01393',
#  'brain_images\\BraTS2021_01394',
#  'brain_images\\BraTS2021_01395',
#  'brain_images\\BraTS2021_01396',
#  'brain_images\\BraTS2021_01397',
#  'brain_images\\BraTS2021_01398',
#  'brain_images\\BraTS2021_01399',
#  'brain_images\\BraTS2021_01400',
#  'brain_images\\BraTS2021_01401',
#  'brain_images\\BraTS2021_01402',
#  'brain_images\\BraTS2021_01403',
#  'brain_images\\BraTS2021_01404',
#  'brain_images\\BraTS2021_01405',
#  'brain_images\\BraTS2021_01406',
#  'brain_images\\BraTS2021_01407',
#  'brain_images\\BraTS2021_01408',
#  'brain_images\\BraTS2021_01409',
#  'brain_images\\BraTS2021_01410',
#  'brain_images\\BraTS2021_01411',
#  'brain_images\\BraTS2021_01412',
#  'brain_images\\BraTS2021_01413',
#  'brain_images\\BraTS2021_01414',
#  'brain_images\\BraTS2021_01415',
#  ...]

# %%
def fetchingDatafromPath(dirList):
    x = []
    for i in range(0,len(dirList)):
        x.append(dirList[i][dirList[i].rfind('/')+1:])
    return x

train_and_test_ids = fetchingDatafromPath(train_and_val_directories); 

train_test_ids, val_ids = train_test_split(train_and_test_ids,test_size=0.2)

train_ids, test_ids = train_test_split(train_test_ids,test_size=0.05)

len(train_ids)
# Out:
# 950

# %%
Total_image_slices = 128 
starting_image_slice = 22 

# Total_image_slices = 64 
# starting_image_slice = 50

# %% [markdown]
# # Model Creation

# %%
def CNN(input_mat,num_filters,kernel_size,batch_norm):
  # Input layer 
  inp = Conv3D(num_filters,kernel_size=(kernel_size,kernel_size,kernel_size),strides=(1,1,1),padding='same')(input_mat)
  # Starting batch normalization
  if batch_norm:
    inp = BatchNormalization()(inp)
  # Initiating activation function
  inp = Activation('relu')(inp)

  inp = Conv3D(num_filters,kernel_size=(kernel_size,kernel_size,kernel_size),strides=(1,1,1),padding='same')(inp)
  if batch_norm:
    inp = BatchNormalization()(inp)
  
  inp = Activation('relu')(inp)
    
  inp = add([input_mat,inp])
  
  return inp


def ThreeD_Vnet(input_img, n_filters = 8, dropout = 0.2, batch_norm = True):

  # Convolutional layer 1
  cnn1 = Conv3D(n_filters,kernel_size = (5,5,5) , strides = (1,1,1) , padding='same')(input_img)
  # Convolutional layer 2
  cnn2 = Conv3D(n_filters*2,kernel_size = (2,2,2) , strides = (2,2,2) , padding = 'same' )(cnn1)
  # Convolutional layer 3 
  cnn3 = CNN(cnn2 , n_filters*2,5,True)
  # Padding layer 
  pdd3 = Conv3D(n_filters*4,kernel_size = (2,2,2) , strides = (2,2,2), padding = 'same')(cnn3)
  pdd3 = Dropout(dropout)(pdd3)
  # Convolutional layer 4
  cnn4 = CNN(pdd3, n_filters*4,5,True)
  pdd4 = Conv3D(n_filters*8,kernel_size = (2,2,2) , strides = (2,2,2) , padding='same')(cnn4)
  pdd4 = Dropout(dropout)(pdd4)
  # Convolutional layer 5  
  cnn5 = CNN(pdd4, n_filters*8,5,True)
  pdd6 = Conv3D(n_filters*16,kernel_size = (2,2,2) , strides = (2,2,2) , padding='same')(cnn5)
  pdd6 = Dropout(dropout)(pdd6)
 
  pdd7 = CNN(pdd6,n_filters*16,5,True)
  # Convolutional layer 7  
  f6 = Conv3DTranspose(n_filters*8, (2,2,2), strides=(2, 2, 2), padding='same')(pdd7)
  f6 = concatenate([f6,cnn5])
  cnn7 = CNN(f6,n_filters*16,5,True)
  cnn7 = Dropout(dropout)(cnn7)
  u7 = Conv3DTranspose(n_filters*4,(2,2,2),strides = (2,2,2) , padding= 'same')(cnn7)

  # Convolutional layer 8
  u8 = concatenate([u7,cnn4])
  cnn8 = CNN(u8,n_filters*8,5,True)
  cnn8 = Dropout(dropout)(cnn8)
  f9 = Conv3DTranspose(n_filters*2,(2,2,2),strides = (2,2,2) , padding= 'same')(cnn8)
   # Convolutional layer 9 
  f9 = concatenate([f9,cnn3])
  cnn9 = CNN(f9,n_filters*4,5,True)
  cnn9 = Dropout(dropout)(cnn9)
  f10 = Conv3DTranspose(n_filters,(2,2,2),strides = (2,2,2) , padding= 'same')(cnn9)
  
  # Convolutional layer 10
  f10 = concatenate([f10,cnn1])
  cnn10 = Conv3D(n_filters*2,kernel_size = (5,5,5),strides = (1,1,1) , padding = 'same')(f10)
  cnn10 = Dropout(dropout)(cnn10)
  cnn10 = add([cnn10,f10])
  
  # Output layer 
  output = Conv3D(4, (1,1,1), activation='softmax')(cnn10)

  model = Model(inputs=input_img, outputs=output)

  return model

# %% [markdown]
# # Creating Data for model

# %%
keras = tf.compat.v1.keras
Sequence = keras.utils.Sequence

class CreatingModelData(Sequence):

    def __init__(self, list_IDs, dim=(image_size,image_size), batch_size = 1, n_channels = 4, shuffle=True):
       
        self.dim = dim
        self.batch_size = batch_size
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.shuffle = shuffle
        self.ending_epoch()
        print("Total Modalities Used:", n_channels)

    def __len__(self):
        # batches in each epoch
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
       # batch initailizing
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        # looking for ids list
        Batch_ids = [self.list_IDs[k] for k in indexes]

        X, y = self.__creating_data(Batch_ids)

        return X, y
    
    
    def getitem(self, index):
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        
        Batch_ids = [self.list_IDs[k] for k in indexes]
        X, y = self.__creating_data(Batch_ids)

        return X, y

    def ending_epoch(self):
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __creating_data(self, Batch_ids):
       
        X = np.zeros((self.batch_size*Total_image_slices, *self.dim, self.n_channels))
        y = np.zeros((self.batch_size*Total_image_slices, 128, 128))
        Y = np.zeros((self.batch_size*Total_image_slices, *self.dim, 4))

       
        
        # Creating data
        for c, i in enumerate(Batch_ids):

            case_path = os.path.join(Training_data_directory, i)

            xyz = os.listdir(i)
            xyz.sort()
            
            # Fetching t1 data
            data_path = os.path.join(i,xyz[2])
            t1 = nib.load(data_path).get_fdata() 

            # Fetching flair data
            data_path = os.path.join(i,xyz[0])
            flair = nib.load(data_path).get_fdata() 

            # Fetching t2 data
            data_path = os.path.join(i,xyz[4])
            t2 = nib.load(data_path).get_fdata()

            # Fetching t1ce data
            data_path = os.path.join(i,xyz[3])
            ce = nib.load(data_path).get_fdata()
  
            # Fetching seg data
            data_path = os.path.join(i,xyz[1])
            seg = nib.load(data_path).get_fdata()
        
            for j in range(Total_image_slices):
                # print("A", end = " ")
                if self.n_channels > 0:
                    X[j+(Total_image_slices*c),:,:,0] = cv2.resize(t1[:,:,j+starting_image_slice], (image_size, image_size)) 

                if self.n_channels > 1:
                    X[j+(Total_image_slices*c),:,:,1] = cv2.resize(flair[:,:,j+starting_image_slice], (image_size, image_size))
                
                if self.n_channels > 2:
                    X[j+(Total_image_slices*c),:,:,2] = cv2.resize(t2[:,:,j+starting_image_slice], (image_size, image_size))

                if self.n_channels > 3:
                    X[j+(Total_image_slices*c),:,:,3] = cv2.resize(ce[:,:,j+starting_image_slice], (image_size, image_size))

                y[j +Total_image_slices*c,:,:] = cv2.resize(seg[:,:,j+starting_image_slice], (image_size, image_size))


        X = X.reshape(self.batch_size,128,128,128,self.n_channels)
        y = y.reshape(self.batch_size,128,128,128)

        # Generate masks
        y[y==4] = 3
        y = tf.one_hot(y, 4)

        return X/np.max(X), y

# %% [markdown]
# ## Model2: Using only one modalities

# %%
creating_training_data = CreatingModelData(train_ids, n_channels=1)
creating_validation_data = CreatingModelData(val_ids, n_channels=1)
creating_testing_data = CreatingModelData(test_ids, n_channels=1)
# Out:
# Total Modalities Used: 1
# Total Modalities Used: 1
# Total Modalities Used: 1

# %%
input_layer = Input((128,image_size, image_size, 1))

model2 = ThreeD_Vnet(input_layer)
model2.compile(loss="categorical_crossentropy", optimizer=Adam(learning_rate=0.001), metrics = ['accuracy',tf.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity, hausdorff] )

model2.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 28, 1)]
#
#  conv3d (Conv3D)                (None, 128, 128, 12  1008        ['input_1[0][0]']
#                                 8, 8)
#
#  conv3d_1 (Conv3D)              (None, 64, 64, 64,   1040        ['conv3d[0][0]']
#                                 16)
#
#  conv3d_2 (Conv3D)              (None, 64, 64, 64,   32016       ['conv3d_1[0][0]']
#                                 16)
#
#  batch_normalization (BatchNorm  (None, 64, 64, 64,   64         ['conv3d_2[0][0]']
#  alization)                     16)
#
#  activation (Activation)        (None, 64, 64, 64,   0           ['batch_normalization[0][0]']
#                                 16)
#
#  conv3d_3 (Conv3D)              (None, 64, 64, 64,   32016       ['activation[0][0]']
#                                 16)
#
#  batch_normalization_1 (BatchNo  (None, 64, 64, 64,   64         ['conv3d_3[0][0]']
#  rmalization)                   16)
#
#  activation_1 (Activation)      (None, 64, 64, 64,   0           ['batch_normalization_1[0][0]']
#                                 16)
#
#  add (Add)                      (None, 64, 64, 64,   0           ['conv3d_1[0][0]',
#                                 16)                               'activation_1[0][0]']
#
#  conv3d_4 (Conv3D)              (None, 32, 32, 32,   4128        ['add[0][0]']
#                                 32)
#
#  dropout (Dropout)              (None, 32, 32, 32,   0           ['conv3d_4[0][0]']
#                                 32)
#
#  conv3d_5 (Conv3D)              (None, 32, 32, 32,   128032      ['dropout[0][0]']
#                                 32)
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 32,   128        ['conv3d_5[0][0]']
#  rmalization)                   32)
#
#  activation_2 (Activation)      (None, 32, 32, 32,   0           ['batch_normalization_2[0][0]']
#                                 32)
#
#  conv3d_6 (Conv3D)              (None, 32, 32, 32,   128032      ['activation_2[0][0]']
#                                 32)
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 32,   128        ['conv3d_6[0][0]']
#  rmalization)                   32)
#
#  activation_3 (Activation)      (None, 32, 32, 32,   0           ['batch_normalization_3[0][0]']
#                                 32)
#
#  add_1 (Add)                    (None, 32, 32, 32,   0           ['dropout[0][0]',
#                                 32)                               'activation_3[0][0]']
#
#  conv3d_7 (Conv3D)              (None, 16, 16, 16,   16448       ['add_1[0][0]']
#                                 64)
#
#  dropout_1 (Dropout)            (None, 16, 16, 16,   0           ['conv3d_7[0][0]']
#                                 64)
#
#  conv3d_8 (Conv3D)              (None, 16, 16, 16,   512064      ['dropout_1[0][0]']
#                                 64)
#
#  batch_normalization_4 (BatchNo  (None, 16, 16, 16,   256        ['conv3d_8[0][0]']
#  rmalization)                   64)
#
#  activation_4 (Activation)      (None, 16, 16, 16,   0           ['batch_normalization_4[0][0]']
#                                 64)
#
#  conv3d_9 (Conv3D)              (None, 16, 16, 16,   512064      ['activation_4[0][0]']
#                                 64)
#
#  batch_normalization_5 (BatchNo  (None, 16, 16, 16,   256        ['conv3d_9[0][0]']
#  rmalization)                   64)
#
#  activation_5 (Activation)      (None, 16, 16, 16,   0           ['batch_normalization_5[0][0]']
#                                 64)
#
#  add_2 (Add)                    (None, 16, 16, 16,   0           ['dropout_1[0][0]',
#                                 64)                               'activation_5[0][0]']
#
#  conv3d_10 (Conv3D)             (None, 8, 8, 8, 128  65664       ['add_2[0][0]']
#                                 )
#
#  dropout_2 (Dropout)            (None, 8, 8, 8, 128  0           ['conv3d_10[0][0]']
#                                 )
#
#  conv3d_11 (Conv3D)             (None, 8, 8, 8, 128  2048128     ['dropout_2[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 8, 8, 8, 128  512        ['conv3d_11[0][0]']
#  rmalization)                   )
#
#  activation_6 (Activation)      (None, 8, 8, 8, 128  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  conv3d_12 (Conv3D)             (None, 8, 8, 8, 128  2048128     ['activation_6[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 8, 8, 8, 128  512        ['conv3d_12[0][0]']
#  rmalization)                   )
#
#  activation_7 (Activation)      (None, 8, 8, 8, 128  0           ['batch_normalization_7[0][0]']
#                                 )
#
#  add_3 (Add)                    (None, 8, 8, 8, 128  0           ['dropout_2[0][0]',
#                                 )                                 'activation_7[0][0]']
#
#  conv3d_transpose (Conv3DTransp  (None, 16, 16, 16,   65600      ['add_3[0][0]']
#  ose)                           64)
#
#  concatenate (Concatenate)      (None, 16, 16, 16,   0           ['conv3d_transpose[0][0]',
#                                 128)                              'add_2[0][0]']
#
#  conv3d_13 (Conv3D)             (None, 16, 16, 16,   2048128     ['concatenate[0][0]']
#                                 128)
#
#  batch_normalization_8 (BatchNo  (None, 16, 16, 16,   512        ['conv3d_13[0][0]']
#  rmalization)                   128)
#
#  activation_8 (Activation)      (None, 16, 16, 16,   0           ['batch_normalization_8[0][0]']
#                                 128)
#
#  conv3d_14 (Conv3D)             (None, 16, 16, 16,   2048128     ['activation_8[0][0]']
#                                 128)
#
#  batch_normalization_9 (BatchNo  (None, 16, 16, 16,   512        ['conv3d_14[0][0]']
#  rmalization)                   128)
#
#  activation_9 (Activation)      (None, 16, 16, 16,   0           ['batch_normalization_9[0][0]']
#                                 128)
#
#  add_4 (Add)                    (None, 16, 16, 16,   0           ['concatenate[0][0]',
#                                 128)                              'activation_9[0][0]']
#
#  dropout_3 (Dropout)            (None, 16, 16, 16,   0           ['add_4[0][0]']
#                                 128)
#
#  conv3d_transpose_1 (Conv3DTran  (None, 32, 32, 32,   32800      ['dropout_3[0][0]']
#  spose)                         32)
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 32,   0           ['conv3d_transpose_1[0][0]',
#                                 64)                               'add_1[0][0]']
#
#  conv3d_15 (Conv3D)             (None, 32, 32, 32,   512064      ['concatenate_1[0][0]']
#                                 64)
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 32,   256        ['conv3d_15[0][0]']
#  ormalization)                  64)
#
#  activation_10 (Activation)     (None, 32, 32, 32,   0           ['batch_normalization_10[0][0]']
#                                 64)
#
#  conv3d_16 (Conv3D)             (None, 32, 32, 32,   512064      ['activation_10[0][0]']
#                                 64)
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 32,   256        ['conv3d_16[0][0]']
#  ormalization)                  64)
#
#  activation_11 (Activation)     (None, 32, 32, 32,   0           ['batch_normalization_11[0][0]']
#                                 64)
#
#  add_5 (Add)                    (None, 32, 32, 32,   0           ['concatenate_1[0][0]',
#                                 64)                               'activation_11[0][0]']
#
#  dropout_4 (Dropout)            (None, 32, 32, 32,   0           ['add_5[0][0]']
#                                 64)
#
#  conv3d_transpose_2 (Conv3DTran  (None, 64, 64, 64,   8208       ['dropout_4[0][0]']
#  spose)                         16)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 64,   0           ['conv3d_transpose_2[0][0]',
#                                 32)                               'add[0][0]']
#
#  conv3d_17 (Conv3D)             (None, 64, 64, 64,   128032      ['concatenate_2[0][0]']
#                                 32)
#
#  batch_normalization_12 (BatchN  (None, 64, 64, 64,   128        ['conv3d_17[0][0]']
#  ormalization)                  32)
#
#  activation_12 (Activation)     (None, 64, 64, 64,   0           ['batch_normalization_12[0][0]']
#                                 32)
#
#  conv3d_18 (Conv3D)             (None, 64, 64, 64,   128032      ['activation_12[0][0]']
#                                 32)
#
#  batch_normalization_13 (BatchN  (None, 64, 64, 64,   128        ['conv3d_18[0][0]']
#  ormalization)                  32)
#
#  activation_13 (Activation)     (None, 64, 64, 64,   0           ['batch_normalization_13[0][0]']
#                                 32)
#
#  add_6 (Add)                    (None, 64, 64, 64,   0           ['concatenate_2[0][0]',
#                                 32)                               'activation_13[0][0]']
#
#  dropout_5 (Dropout)            (None, 64, 64, 64,   0           ['add_6[0][0]']
#                                 32)
#
#  conv3d_transpose_3 (Conv3DTran  (None, 128, 128, 12  2056       ['dropout_5[0][0]']
#  spose)                         8, 8)
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 12  0           ['conv3d_transpose_3[0][0]',
#                                 8, 16)                            'conv3d[0][0]']
#
#  conv3d_19 (Conv3D)             (None, 128, 128, 12  32016       ['concatenate_3[0][0]']
#                                 8, 16)
#
#  dropout_6 (Dropout)            (None, 128, 128, 12  0           ['conv3d_19[0][0]']
#                                 8, 16)
#
#  add_7 (Add)                    (None, 128, 128, 12  0           ['dropout_6[0][0]',
#                                 8, 16)                            'concatenate_3[0][0]']
#
#  conv3d_20 (Conv3D)             (None, 128, 128, 12  68          ['add_7[0][0]']
#                                 8, 4)
#
# ==================================================================================================
# Total params: 11,049,676
# Trainable params: 11,047,820
# Non-trainable params: 1,856
# __________________________________________________________________________________________________

# %%
if "yes" in input("Are you sure to Train Model? yes or no").lower():
    pass
else:
    raise Exception("Skip the next 6 Blocks and Run after that for directly showing Output")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[23], line 4
#       2     pass
#       3 else:
# ----> 4     raise Exception("Skip the next 6 Blocks and Run after that for directly showing Output")
#
# Exception: Skip the next 6 Blocks and Run after that for directly showing Output

# %%
earlyStopping = EarlyStopping(monitor='val_loss', patience=10, verbose=0, mode='min')
mcp_save = ModelCheckpoint('one.mdl_wts.hdf5', save_best_only=True, monitor='val_loss', mode='min', restore_best_weights=True)
reduce_lr_loss = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=7, verbose=1, min_delta=1e-4, mode='min')

history =  model2.fit(creating_training_data, epochs=30, batch_size=4, steps_per_epoch= 200, validation_data = creating_validation_data, verbose=1, callbacks=[earlyStopping, mcp_save, reduce_lr_loss]) 
model2.save("model_vnet_1mod.h5")
# Out:
# Epoch 1/30
# 200/200 [==============================] - 250s 1s/step - loss: 0.0895 - accuracy: 0.9794 - mean_io_u: 0.6312 - dice_coef: 0.2863 - precision: 0.9810 - sensitivity: 0.9734 - specificity: 0.9952 - hausdorff: 1.8512 - val_loss: 0.0895 - val_accuracy: 0.9876 - val_mean_io_u: 0.3788 - val_dice_coef: 0.2521 - val_precision: 0.9876 - val_sensitivity: 0.9876 - val_specificity: 0.9959 - val_hausdorff: 1.5861 - lr: 0.0010
# Epoch 2/30
# 200/200 [==============================] - 237s 1s/step - loss: 0.0611 - accuracy: 0.9868 - mean_io_u: 0.4743 - dice_coef: 0.3055 - precision: 0.9871 - sensitivity: 0.9864 - specificity: 0.9957 - hausdorff: 1.6528 - val_loss: 0.0563 - val_accuracy: 0.9876 - val_mean_io_u: 0.3753 - val_dice_coef: 0.3193 - val_precision: 0.9878 - val_sensitivity: 0.9873 - val_specificity: 0.9959 - val_hausdorff: 1.5662 - lr: 0.0010
# Epoch 3/30
# 200/200 [==============================] - 238s 1s/step - loss: 0.0545 - accuracy: 0.9874 - mean_io_u: 0.4531 - dice_coef: 0.3187 - precision: 0.9880 - sensitivity: 0.9870 - specificity: 0.9960 - hausdorff: 1.5287 - val_loss: 0.0843 - val_accuracy: 0.9876 - val_mean_io_u: 0.3820 - val_dice_coef: 0.2554 - val_precision: 0.9876 - val_sensitivity: 0.9876 - val_specificity: 0.9959 - val_hausdorff: 1.5861 - lr: 0.0010
# Epoch 4/30
# 200/200 [==============================] - 233s 1s/step - loss: 0.0539 - accuracy: 0.9870 - mean_io_u: 0.4400 - dice_coef: 0.3342 - precision: 0.9886 - sensitivity: 0.9859 - specificity: 0.9962 - hausdorff: 1.4511 - val_loss: 0.0595 - val_accuracy: 0.9840 - val_mean_io_u: 0.3750 - val_dice_coef: 0.3401 - val_precision: 0.9907 - val_sensitivity: 0.9788 - val_specificity: 0.9969 - val_hausdorff: 1.1878 - lr: 0.0010
# Epoch 5/30
# 200/200 [==============================] - 233s 1s/step - loss: 0.
30
# 200/200 [==============================] - 233s 1s/step - loss: 0.0325 - accuracy: 0.9888 - mean_io_u: 0.4287 - dice_coef: 0.4711 - precision: 0.9943 - sensitivity: 0.9848 - specificity: 0.9981 - hausdorff: 0.7271 - val_loss: 0.0487 - val_accuracy: 0.9884 - val_mean_io_u: 0.3770 - val_dice_coef: 0.3372 - val_precision: 0.9907 - val_sensitivity: 0.9870 - val_specificity: 0.9969 - val_hausdorff: 1.1830 - lr: 0.0010
# Epoch 26/30
# 200/200 [==============================] - 233s 1s/step - loss: 0.0294 - accuracy: 0.9899 - mean_io_u: 0.4189 - dice_coef: 0.4822 - precision: 0.9948 - sensitivity: 0.9861 - specificity: 0.9983 - hausdorff: 0.6586 - val_loss: 0.0572 - val_accuracy: 0.9805 - val_mean_io_u: 0.8021 - val_dice_coef: 0.4637 - val_precision: 0.9932 - val_sensitivity: 0.9753 - val_specificity: 0.9978 - val_hausdorff: 0.8424 - lr: 0.0010
# Epoch 27/30
# 200/200 [==============================] - 233s 1s/step - loss: 0.0308 - accuracy: 0.9892 - mean_io_u: 0.4225 - dice_coef: 0.4803 - precision: 0.9948 - sensitivity: 0.9853 - specificity: 0.9983 - hausdorff: 0.6539 - val_loss: 0.0406 - val_accuracy: 0.9890 - val_mean_io_u: 0.3751 - val_dice_coef: 0.3675 - val_precision: 0.9914 - val_sensitivity: 0.9875 - val_specificity: 0.9971 - val_hausdorff: 1.0963 - lr: 0.0010
# Epoch 28/30
# 200/200 [==============================] - 231s 1s/step - loss: 0.0310 - accuracy: 0.9893 - mean_io_u: 0.4160 - dice_coef: 0.4889 - precision: 0.9946 - sensitivity: 0.9852 - specificity: 0.9982 - hausdorff: 0.6825 - val_loss: 0.0378 - val_accuracy: 0.9875 - val_mean_io_u: 0.3825 - val_dice_coef: 0.4397 - val_precision: 0.9947 - val_sensitivity: 0.9835 - val_specificity: 0.9982 - val_hausdorff: 0.6766 - lr: 0.0010
# Epoch 29/30
# 200/200 [==============================] - 233s 1s/step - loss: 0.0299 - accuracy: 0.9897 - mean_io_u: 0.4359 - dice_coef: 0.4824 - precision: 0.9945 - sensitivity: 0.9858 - specificity: 0.9982 - hausdorff: 0.6970 - val_loss: 0.0410 - val_accuracy: 0.9857 - val_mean_io_u: 0.3923 - val_dice_coef: 0.4556 - val_precision: 0.9950 - val_sensitivity: 0.9806 - val_specificity: 0.9984 - val_hausdorff: 0.6249 - lr: 0.0010
# Epoch 30/30
# 200/200 [==============================] - 233s 1s/step - loss: 0.0319 - accuracy: 0.9891 - mean_io_u: 0.4168 - dice_coef: 0.4819 - precision: 0.9941 - sensitivity: 0.9851 - specificity: 0.9981 - hausdorff: 0.7487 - val_loss: 0.0553 - val_accuracy: 0.9880 - val_mean_io_u: 0.3758 - val_dice_coef: 0.3090 - val_precision: 0.9890 - val_sensitivity: 0.9876 - val_specificity: 0.9963 - val_hausdorff: 1.4047 - lr: 0.0010

# %%
print("Evaluate on test data")
results = model2.evaluate(creating_testing_data)
print("test loss, test acc:", results)
# Out:
# Evaluate on test data
# 50/50 [==============================] - 26s 525ms/step - loss: 0.0615 - accuracy: 0.9875 - mean_io_u: 0.3761 - dice_coef: 0.2959 - precision: 0.9887 - sensitivity: 0.9871 - specificity: 0.9962 - hausdorff: 1.4403
# test loss, test acc: [0.06151384487748146, 0.9875359535217285, 0.3761154115200043, 0.29585734009742737, 0.9887247681617737, 0.9870849847793579, 0.9962493181228638, 1.440252661705017]

# %% [markdown]
# # Model Accuracy Graph

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.subplots_adjust(top=1.00, bottom=0.0, left=0.0, right=0.95, hspace=0.25,wspace=0.35)
plt.show()

# %% [markdown]
# # Model Loss Graph

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.subplots_adjust(top=1.00, bottom=0.0, left=0.0, right=0.95, hspace=0.25,
                    wspace=0.35)
plt.show()

# %% [markdown]
# # Model Dice Coef Graph

# %%
plt.plot(history.history['dice_coef'])
plt.plot(history.history['val_dice_coef'])
plt.title('Dice Coef')
plt.ylabel('Dice Coef')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.subplots_adjust(top=1.00, bottom=0.0, left=0.0, right=0.95, hspace=0.25,wspace=0.35)
plt.show()

# %% [markdown]
# # Model Hausdroff Dist Graph

# %%
plt.plot(history.history['hausdorff'])
plt.plot(history.history['val_hausdorff'])
plt.title('hausdorff')
plt.ylabel('hausdorff')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.subplots_adjust(top=1.00, bottom=0.0, left=0.0, right=0.95, hspace=0.25,wspace=0.35)
plt.show()

# %% [markdown]
# ## Training completed for all modalities model
#
# # **********************************************************

# %% [markdown]
# # Loading the all modalities Pre-Trained model (Run From Here for showing Run Output)

# %%
loaded_model_all = keras.models.load_model('model_vnet_1mod.h5', compile=False)
op = loaded_model_all.predict(creating_testing_data)
# Out:
# 50/50 [==============================] - 28s 490ms/step

# %% [markdown]
# # Result

# %% [markdown]
# # Input Real image

# %%
image_num = 15

# %%
inp_test = np.array(creating_testing_data.getitem(image_num)[0])
inp_test.shape
inp_test = tf.convert_to_tensor(inp_test, dtype=float, name='inp_test')
inp_test.shape
# Out:
# TensorShape([1, 128, 128, 128, 1])

# %%
def visualise_flair(layer):
    mask = inp_test[0]
    plt.imshow(mask[:,:,layer,0],cmap ='bone')
    plt.axis('off')
    plt.tight_layout()

interact(visualise_flair, layer=(0, inp_test[0].shape[2] - 1))
# Out:
# interactive(children=(IntSlider(value=63, description='layer', max=127), Output()), _dom_classes=('widget-inte…
# <function __main__.visualise_flair(layer)>

# %% [markdown]
# # Segmented part of image

# %%
seg_test = creating_testing_data.getitem(image_num)[1]
seg_test.shape
# Out:
# TensorShape([1, 128, 128, 128, 4])

# %%
def visualise_seg(layer):
    mask = seg_test[0]
    print(mask[:,:,layer].shape)
    plt.imshow(mask[:,:,layer])
    plt.axis('off')
    plt.tight_layout()

 

interact(visualise_seg, layer=(0, seg_test[0].shape[2] - 1))
# Out:
# interactive(children=(IntSlider(value=63, description='layer', max=127), Output()), _dom_classes=('widget-inte…
# <function __main__.visualise_seg(layer)>

# %% [markdown]
# # Model predicted image

# %%
def visualize_pred(layer):
    mask = op[image_num]
    print(mask[:,:,layer].shape)
    plt.imshow((mask[:,:,layer])*10)
    plt.axis('off')
    plt.tight_layout()


interact(visualize_pred, layer=(0, op[image_num].shape[2] - 1))
# Out:
# interactive(children=(IntSlider(value=63, description='layer', max=127), Output()), _dom_classes=('widget-inte…
# <function __main__.visualize_pred(layer)>
